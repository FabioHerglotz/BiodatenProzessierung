# %% [markdown]
# # Interesaante Sachen

# %%
pwd
# Out:
# /home/schoen/notebooks

# %%
# new command
dorado -h
# Out:
# [2025-11-04 11:53:38.723] [info] Running: "-h"
# Usage: dorado [options] subcommand
#
# Positional arguments:
# aligner
# basecaller
# correct
# demux
# download
# duplex
# polish
# summary
# trim
# variant
#
# Optional arguments:
# -h --help               shows help message and exits
# -v --version            prints version information and exits
# -vv                     prints verbose version information and exits
